# %%
from pathlib import Path

import logfire

from src.ingestion.parser.google_doc_ai import GoogleDocAI

# %%
logfire.configure(service_name="Google Document AI")

# %%
cwd = Path.cwd().parent
file_path = cwd / "data/Attention-is_all_you_need.pdf"

# %%
parser = GoogleDocAI()

# %%
parser.check_installation()

# %%
parse_result = parser.parse_pdf(file_path=file_path)

# %%
parse_result
